# %%
import pandas as pd
df = pd.read_csv("pd_speech_features.csv")
df.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Baseline Features Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         id     gender               PPE        DFA       RPDE  numPulses
# 1          0          1           0.85247    0.71826    0.57227        240
# 2          0          1           0.76686    0.69481    0.53966        234
# 3          0          1           0.85083    0.67604    0.58982        232
# 4          1          0           0.41121    0.79672    0.59257        178
#
#          Unnamed: 6        Unnamed: 7          Unnamed: 8    Unnamed: 9  ...  \
# 0  numPeriodsPulses  meanPeriodPulses  stdDevPeriodPulses  locPctJitter  ...
# 1               239        0.00806353            8.68E-05       0.00218  ...
# 2               233       0.008258256            7.31E-05       0.00195  ...
# 3               231        0.00833959            6.04E-05       0.00176  ...
# 4               177       0.010857733         0.000182739       0.00419  ...
#
#                 Unnamed: 745               Unnamed: 746  \
# 0  tqwt_kurtosisValue_dec_28  tqwt_kurtosisValue_dec_29
# 1                      1.562                     2.6445
# 2                     1.5589                     3.6107
# 3                     1.5643                     2.3308
# 4                     3.7805                     3.5664
#
#                 Unnamed: 747               Unnamed: 748  \
# 0  tqwt_kurtosisValue_dec_30  tqwt_kurtosisValue_dec_31
# 1                     3.8686                     4.2105
# 2                    23.5155                    14.1962
# 3                     9.4959                    10.7458
# 4                     5.2558                    14.0403
#
#                 Unnamed: 749               Unnamed: 750  \
# 0  tqwt_kurtosisValue_dec_32  tqwt_kurtosisValue_dec_33
# 1                     5.1221                     4.4625
# 2                    11.0261                     9.5082
# 3                    11.0177                     4.8066
# 4                     4.2235                     4.6857
#
#                 Unnamed: 751               Unnamed: 752  \
# 0  tqwt_kurtosisValue_dec_34  tqwt_kurtosisValue_dec_35
# 1                     2.6202                     3.0004
# 2                     6.5245                     6.3431
# 3                     2.9199                     3.1495
# 4                      4.846                      6.265
#
#                 Unnamed: 753 Unnamed: 754
# 0  tqwt_kurtosisValue_dec_36        class
# 1                    18.9405            1
# 2                     45.178            1
# 3                     4.7666            1
# 4                     4.0603            1
#
# [5 rows x 755 columns]

# %% [markdown]
# The first row must be the header!

# %%
new_header = df.iloc[0]
df = df[1:]
df.columns = new_header
df.head()
# Out:
# 0 id gender      PPE      DFA     RPDE numPulses numPeriodsPulses  \
# 1  0      1  0.85247  0.71826  0.57227       240              239
# 2  0      1  0.76686  0.69481  0.53966       234              233
# 3  0      1  0.85083  0.67604  0.58982       232              231
# 4  1      0  0.41121  0.79672  0.59257       178              177
# 5  1      0   0.3279  0.79782  0.53028       236              235
#
# 0 meanPeriodPulses stdDevPeriodPulses locPctJitter  ...  \
# 1       0.00806353           8.68E-05      0.00218  ...
# 2      0.008258256           7.31E-05      0.00195  ...
# 3       0.00833959           6.04E-05      0.00176  ...
# 4      0.010857733        0.000182739      0.00419  ...
# 5      0.008161574        0.002668863      0.00535  ...
#
# 0 tqwt_kurtosisValue_dec_28 tqwt_kurtosisValue_dec_29  \
# 1                     1.562                    2.6445
# 2                    1.5589                    3.6107
# 3                    1.5643                    2.3308
# 4                    3.7805                    3.5664
# 5                    6.1727                    5.8416
#
# 0 tqwt_kurtosisValue_dec_30 tqwt_kurtosisValue_dec_31  \
# 1                    3.8686                    4.2105
# 2                   23.5155                   14.1962
# 3                    9.4959                   10.7458
# 4                    5.2558                   14.0403
# 5                    6.0805                    5.7621
#
# 0 tqwt_kurtosisValue_dec_32 tqwt_kurtosisValue_dec_33  \
# 1                    5.1221                    4.4625
# 2                   11.0261                    9.5082
# 3                   11.0177                    4.8066
# 4                    4.2235                    4.6857
# 5                    7.7817                   11.6891
#
# 0 tqwt_kurtosisValue_dec_34 tqwt_kurtosisValue_dec_35  \
# 1                    2.6202                    3.0004
# 2                    6.5245                    6.3431
# 3                    2.9199                    3.1495
# 4                     4.846                     6.265
# 5                    8.2103                    5.0559
#
# 0 tqwt_kurtosisValue_dec_36 class
# 1                   18.9405     1
# 2                    45.178     1
# 3                    4.7666     1
# 4                    4.0603     1
# 5                    6.1164     1
#
# [5 rows x 755 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 1 to 756
# Columns: 755 entries, id to class
# dtypes: object(755)
# memory usage: 4.4+ MB

# %% [markdown]
# 'id' is irrelevant. So, let's drop it.

# %%
df.drop('id', inplace=True, axis=1)
df
# Out:
# 0   gender      PPE      DFA     RPDE numPulses numPeriodsPulses  \
# 1        1  0.85247  0.71826  0.57227       240              239
# 2        1  0.76686  0.69481  0.53966       234              233
# 3        1  0.85083  0.67604  0.58982       232              231
# 4        0  0.41121  0.79672  0.59257       178              177
# 5        0   0.3279  0.79782  0.53028       236              235
# ..     ...      ...      ...      ...       ...              ...
# 752      0  0.80903  0.56355  0.28385       417              416
# 753      0  0.16084  0.56499  0.59194       415              413
# 754      0  0.88389  0.72335  0.46815       381              380
# 755      0  0.83782   0.7489  0.49823       340              339
# 756      0  0.81304  0.76471  0.46374       340              339
#
# 0   meanPeriodPulses stdDevPeriodPulses locPctJitter locAbsJitter  ...  \
# 1         0.00806353           8.68E-05      0.00218     1.76E-05  ...
# 2        0.008258256           7.31E-05      0.00195     1.61E-05  ...
# 3         0.00833959           6.04E-05      0.00176     1.47E-05  ...
# 4        0.010857733        0.000182739      0.00419     4.55E-05  ...
# 5        0.008161574        0.002668863      0.00535     4.37E-05  ...
# ..               ...                ...          ...          ...  ...
# 752      0.004626942           5.22E-05      0.00064     2.97E-06  ...
# 753      0.004549703        0.000219994      0.00143     6.50E-06  ...
# 754      0.005069271        0.000102654      0.00076     3.87E-06  ...
# 755      0.005679019           5.51E-05      0.00092     5.24E-06  ...
# 756      0.005675776           3.71E-05      0.00078     4.40E-06  ...
#
# 0   tqwt_kurtosisValue_dec_28 tqwt_kurtosisValue_dec_29  \
# 1                       1.562                    2.6445
# 2                      1.5589                    3.6107
# 3                      1.5643                    2.3308
# 4                      3.7805                    3.5664
# 5                      6.1727                    5.8416
# ..                        ...                       ...
# 752                    3.0706                     3.019
# 753                    1.9704                    1.7451
# 754                   51.5607                   44.4641
# 755                   19.1607                   12.8312
# 756                   62.9927                   21.8152
#
# 0   tqwt_kurtosisValue_dec_30 tqwt_kurtosisValue_dec_31  \
# 1                      3.8686                    4.2105
# 2                     23.5155                   14.1962
# 3                      9.4959                   10.7458
# 4                      5.2558                   14.0403
# 5                      6.0805                    5.7621
# ..                        ...                       ...
# 752                    3.1212                    2.4921
# 753                    1.8277                    2.4976
# 754                   26.1586                    6.3076
# 755                    8.9434                    2.2044
# 756                    9.2457                    4.8555
#
# 0   tqwt_kurtosisValue_dec_32 tqwt_kurtosisValue_dec_33  \
# 1                      5.1221                    4.4625
# 2                     11.0261                    9.5082
# 3                     11.0177                    4.8066
# 4                      4.2235                    4.6857
# 5                      7.7817                   11.6891
# ..                        ...                       ...
# 752                    3.5844                      3.54
# 753                    5.2981                    4.2616
# 754                    2.8601                    2.5361
# 755                    1.9496                    1.9664
# 756                    3.0551                    3.0415
#
# 0   tqwt_kurtosisValue_dec_34 tqwt_kurtosisValue_dec_35  \
# 1                      2.6202                    3.0004
# 2                      6.5245                    6.3431
# 3                      2.9199                    3.1495
# 4                       4.846                     6.265
# 5                      8.2103                    5.0559
# ..                        ...                       ...
# 752                    3.3805                    3.2003
# 753                    6.3042                   10.9058
# 754                    3.5377                    3.3545
# 755                    2.6801                    2.8332
# 756                    4.0116                    2.6217
#
# 0   tqwt_kurtosisValue_dec_36 class
# 1                     18.9405     1
# 2                      45.178     1
# 3                      4.7666     1
# 4                      4.0603     1
# 5                      6.1164     1
# ..                        ...   ...
# 752                    6.8671     0
# 753                    28.417     0
# 754                    5.0424     0
# 755                    3.7131     0
# 756                    3.1527     0
#
# [756 rows x 754 columns]

# %%
df.isnull().sum()
# Out:
# 0
# gender                       0
# PPE                          0
# DFA                          0
# RPDE                         0
# numPulses                    0
#                             ..
# tqwt_kurtosisValue_dec_33    0
# tqwt_kurtosisValue_dec_34    0
# tqwt_kurtosisValue_dec_35    0
# tqwt_kurtosisValue_dec_36    0
# class                        0
# Length: 754, dtype: int64

# %% [markdown]
# There is no missing value.

# %%
df.describe()
# Out:
# 0      gender      PPE      DFA     RPDE numPulses numPeriodsPulses  \
# count     756      756      756      756       756              756
# unique      2      740      745      748       315              319
# top         1  0.82273  0.72248  0.62128       237              236
# freq      390        3        2        2         9                8
#
# 0      meanPeriodPulses stdDevPeriodPulses locPctJitter locAbsJitter  ...  \
# count               756                756          756          756  ...
# unique              755                646          358          543  ...
# top         0.006004477           7.17E-05      0.00076     1.39E-05  ...
# freq                  2                  3            9           10  ...
#
# 0      tqwt_kurtosisValue_dec_28 tqwt_kurtosisValue_dec_29  \
# count                        756                       756
# unique                       749                       755
# top                       1.7726                    4.0251
# freq                           2                         2
#
# 0      tqwt_kurtosisValue_dec_30 tqwt_kurtosisValue_dec_31  \
# count                        756                       756
# unique                       752                       753
# top                       2.8454                    4.2105
# freq                           2                         2
#
# 0      tqwt_kurtosisValue_dec_32 tqwt_kurtosisValue_dec_33  \
# count                        756                       756
# unique                       749                       752
# top                       2.6829                    3.1144
# freq                           2                         2
#
# 0      tqwt_kurtosisValue_dec_34 tqwt_kurtosisValue_dec_35  \
# count                        756                       756
# unique                       753                       753
# top                       12.595                    4.2391
# freq                           2                         2
#
# 0      tqwt_kurtosisValue_dec_36 class
# count                        756   756
# unique                       754     2
# top                       3.2941     1
# freq                           2   564
#
# [4 rows x 754 columns]

# %%
564/756
# Out:
# 0.746031746031746

# %%
df['class'].value_counts()
# Out:
# 1    564
# 0    192
# Name: class, dtype: int64

# %% [markdown]
# There are 2 classes. 564 samples belong to class 1 and 192 samples belong to class 0. If a model predicts 1 for all of the samples its accuracy would be 564/756 = 0.746. So we have to build a model which predicts higher than **74.6**

# %% [markdown]
# if we don't normalize, some models like KNN won't predict well

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
X_train_minmax = min_max_scaler.fit_transform(df.iloc[:, :-1])
df.iloc[:, :-1] = pd.DataFrame(X_train_minmax)

# %%
df.shape
# Out:
# (756, 754)

# %%
# df = df.drop_duplicates()

# %%
# df.shape

# %% [markdown]
# **preprocessing finished**

# %% [markdown]
# shffle:
#
# frac=1 means to return all rows (in random order)

# %%
df=df.sample(frac=1)
df
# Out:
# 0   gender       PPE       DFA      RPDE numPulses numPeriodsPulses  \
# 32     1.0  0.308332  0.338779  0.653048  0.271823         0.272124
# 151    0.0  0.906363  0.284111  0.298049   0.39779          0.39823
# 649    0.0  0.853783  0.407421  0.354302   0.39337         0.393805
# 538    1.0  0.231021  0.776089  0.668433  0.261878         0.262168
# 293    0.0   0.80917  0.374976  0.647357  0.338122         0.338496
# ..     ...       ...       ...       ...       ...              ...
# 5      0.0  0.330615  0.822669  0.524431  0.258564          0.25885
# 178    0.0       0.0  0.504108  0.367944  0.335912         0.336283
# 543    0.0  0.898489   0.41761   0.79475  0.542541         0.543142
# 369    0.0  0.951969  0.589021  0.312178  0.435359         0.435841
# 558    1.0   0.91187  0.710552  0.372993  0.298343         0.298673
#
# 0   meanPeriodPulses stdDevPeriodPulses locPctJitter locAbsJitter  ...  \
# 32          0.522661           0.018549     0.064633     0.057914  ...
# 151         0.296794           0.006135     0.011983     0.008499  ...
# 649         0.302183           0.018462     0.033043     0.020931  ...
# 538         0.551446           0.042456      0.07008     0.064951  ...
# 293         0.380004           0.279767     0.127814     0.088016  ...
# ..               ...                ...          ...          ...  ...
# 5           0.557581           0.765643     0.186638     0.168159  ...
# 178         0.386456           0.637625     0.060639      0.04384  ...
# 543         0.166733           0.005127     0.014524     0.006662  ...
# 369         0.254737           0.339254     0.062818      0.03434  ...
# 558         0.460103           0.016907     0.035221     0.030157  ...
#
# 0   tqwt_kurtosisValue_dec_28 tqwt_kurtosisValue_dec_29  \
# 32                   0.001012                  0.012015
# 151                  0.312984                  0.373946
# 649                  0.444166                  0.422787
# 538                   0.00043                  0.065653
# 293                  0.006507                  0.009145
# ..                        ...                       ...
# 5                    0.019569                  0.021359
# 178                  0.036069                  0.158199
# 543                  0.005564                  0.004772
# 369                  0.033311                  0.016231
# 558                  0.006612                  0.149842
#
# 0   tqwt_kurtosisValue_dec_30 tqwt_kurtosisValue_dec_31  \
# 32                   0.032034                  0.047586
# 151                  0.588175                  0.677659
# 649                  0.731025                  0.681788
# 538                  0.157227                   0.03818
# 293                  0.010466                  0.010983
# ..                        ...                       ...
# 5                    0.037492                  0.039965
# 178                  0.618528                  0.440457
# 543                  0.012144                  0.010068
# 369                  0.031224                  0.161772
# 558                  0.089299                  0.033187
#
# 0   tqwt_kurtosisValue_dec_32 tqwt_kurtosisValue_dec_33  \
# 32                   0.029288                  0.025028
# 151                  0.866139                  0.966175
# 649                  0.507665                   0.35425
# 538                  0.032283                  0.061946
# 293                  0.009477                  0.008751
# ..                        ...                       ...
# 5                    0.071521                  0.139915
# 178                  0.205701                  0.303764
# 543                  0.011644                  0.020362
# 369                  0.412823                  0.420512
# 558                  0.016677                  0.014198
#
# 0   tqwt_kurtosisValue_dec_34 tqwt_kurtosisValue_dec_35  \
# 32                   0.042239                  0.028168
# 151                  0.890584                  0.763033
# 649                  0.273126                  0.231584
# 538                  0.202326                  0.156329
# 293                  0.144579                   0.17543
# ..                        ...                       ...
# 5                    0.105554                  0.055767
# 178                  0.808433                  0.710733
# 543                  0.015047                  0.021346
# 369                   0.44026                  0.566901
# 558                  0.008476                   0.01741
#
# 0   tqwt_kurtosisValue_dec_36 class
# 32                   0.084258     1
# 151                  0.597503     1
# 649                  0.018751     0
# 538                  0.055434     1
# 293                  0.178999     1
# ..                        ...   ...
# 5                    0.024357     1
# 178                  0.558452     1
# 543                  0.006612     0
# 369                  0.532899     1
# 558                  0.002372     1
#
# [756 rows x 754 columns]

# %% [markdown]
# split class:

# %%
y = df["class"]
X =df.iloc[:, :-1]

# %%
y.head()
# Out:
# 32     1
# 151    1
# 649    0
# 538    1
# 293    1
# Name: class, dtype: object

# %%
X.head()
# Out:
# 0   gender       PPE       DFA      RPDE numPulses numPeriodsPulses  \
# 32     1.0  0.308332  0.338779  0.653048  0.271823         0.272124
# 151    0.0  0.906363  0.284111  0.298049   0.39779          0.39823
# 649    0.0  0.853783  0.407421  0.354302   0.39337         0.393805
# 538    1.0  0.231021  0.776089  0.668433  0.261878         0.262168
# 293    0.0   0.80917  0.374976  0.647357  0.338122         0.338496
#
# 0   meanPeriodPulses stdDevPeriodPulses locPctJitter locAbsJitter  ...  \
# 32          0.522661           0.018549     0.064633     0.057914  ...
# 151         0.296794           0.006135     0.011983     0.008499  ...
# 649         0.302183           0.018462     0.033043     0.020931  ...
# 538         0.551446           0.042456      0.07008     0.064951  ...
# 293         0.380004           0.279767     0.127814     0.088016  ...
#
# 0   tqwt_kurtosisValue_dec_27 tqwt_kurtosisValue_dec_28  \
# 32                   0.001538                  0.001012
# 151                  0.307056                  0.312984
# 649                  0.343587                  0.444166
# 538                  0.000661                   0.00043
# 293                  0.004005                  0.006507
#
# 0   tqwt_kurtosisValue_dec_29 tqwt_kurtosisValue_dec_30  \
# 32                   0.012015                  0.032034
# 151                  0.373946                  0.588175
# 649                  0.422787                  0.731025
# 538                  0.065653                  0.157227
# 293                  0.009145                  0.010466
#
# 0   tqwt_kurtosisValue_dec_31 tqwt_kurtosisValue_dec_32  \
# 32                   0.047586                  0.029288
# 151                  0.677659                  0.866139
# 649                  0.681788                  0.507665
# 538                   0.03818                  0.032283
# 293                  0.010983                  0.009477
#
# 0   tqwt_kurtosisValue_dec_33 tqwt_kurtosisValue_dec_34  \
# 32                   0.025028                  0.042239
# 151                  0.966175                  0.890584
# 649                   0.35425                  0.273126
# 538                  0.061946                  0.202326
# 293                  0.008751                  0.144579
#
# 0   tqwt_kurtosisValue_dec_35 tqwt_kurtosisValue_dec_36
# 32                   0.028168                  0.084258
# 151                  0.763033                  0.597503
# 649                  0.231584                  0.018751
# 538                  0.156329                  0.055434
# 293                   0.17543                  0.178999
#
# [5 rows x 753 columns]

# %% [markdown]
# **split train and test (70-30)**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
X_train.head()
# Out:
# 0   gender       PPE       DFA      RPDE numPulses numPeriodsPulses  \
# 9      1.0  0.885234  0.239891   0.48843  0.349171         0.349558
# 432    1.0  0.902368   0.44048  0.473101  0.268508         0.268805
# 428    1.0  0.296728  0.532412  0.442693  0.485083         0.484513
# 511    0.0  0.846093  0.383968  0.474063  0.359116         0.359513
# 131    1.0  0.926476  0.607686  0.223941  0.332597         0.332965
#
# 0   meanPeriodPulses stdDevPeriodPulses locPctJitter locAbsJitter  ...  \
# 9            0.36378           0.016907     0.050835     0.035357  ...
# 432         0.533353           0.015323      0.05846     0.053613  ...
# 428         0.123233           0.038747     0.061365     0.022925  ...
# 511         0.350039           0.017598     0.039942     0.027655  ...
# 131          0.39097           0.015064     0.050835     0.037194  ...
#
# 0   tqwt_kurtosisValue_dec_27 tqwt_kurtosisValue_dec_28  \
# 9                     0.00076                  0.003165
# 432                  0.000592                  0.000307
# 428                  0.116159                  0.221593
# 511                  0.001276                    0.0458
# 131                    0.0006                  0.007533
#
# 0   tqwt_kurtosisValue_dec_29 tqwt_kurtosisValue_dec_30  \
# 9                    0.024123                  0.023621
# 432                  0.275799                  0.627645
# 428                  0.236801                  0.220965
# 511                  0.037585                  0.022372
# 131                  0.008056                  0.007666
#
# 0   tqwt_kurtosisValue_dec_31 tqwt_kurtosisValue_dec_32  \
# 9                    0.025075                  0.022036
# 432                  0.784095                   0.92465
# 428                   0.19663                  0.389768
# 511                  0.031477                   0.08474
# 131                  0.011609                  0.012751
#
# 0   tqwt_kurtosisValue_dec_33 tqwt_kurtosisValue_dec_34  \
# 9                    0.029288                  0.017918
# 432                   0.93937                  0.945393
# 428                  0.418909                  0.335373
# 511                  0.098778                  0.073314
# 131                  0.025849                  0.120511
#
# 0   tqwt_kurtosisValue_dec_35 tqwt_kurtosisValue_dec_36
# 9                    0.029965                    0.0096
# 432                  0.850674                  0.609529
# 428                  0.263033                  0.534796
# 511                  0.114196                  0.041243
# 131                  0.066316                  0.125656
#
# [5 rows x 753 columns]

# %%
X_test.head()
# Out:
# 0   gender       PPE       DFA      RPDE numPulses numPeriodsPulses  \
# 502    1.0  0.880962   0.52604   0.25824  0.281768          0.28208
# 427    1.0  0.362043  0.498835  0.491024  0.456354         0.455752
# 597    1.0  0.282873  0.554344  0.716904  0.312707         0.313053
# 14     0.0  0.888952  0.727211  0.772446  0.334807         0.335177
# 590    0.0  0.891803  0.079867   0.18808  0.502762         0.503319
#
# 0   meanPeriodPulses stdDevPeriodPulses locPctJitter locAbsJitter  ...  \
# 502         0.496038           0.009274     0.029049     0.026951  ...
# 427         0.127912           0.059677     0.072622     0.027499  ...
# 597         0.430069            0.01057     0.040305     0.032346  ...
# 14          0.387654           0.931677     0.116195     0.081761  ...
# 590         0.194972           0.004925     0.013435     0.006935  ...
#
# 0   tqwt_kurtosisValue_dec_27 tqwt_kurtosisValue_dec_28  \
# 502                  0.000544                  0.000431
# 427                  0.082069                  0.163352
# 597                  0.005244                  0.007257
# 14                   0.005158                  0.009624
# 590                  0.558991                  0.672014
#
# 0   tqwt_kurtosisValue_dec_29 tqwt_kurtosisValue_dec_30  \
# 502                  0.208181                  0.614411
# 427                  0.074286                   0.05969
# 597                  0.008046                  0.013335
# 14                   0.007418                  0.006932
# 590                  0.545248                  0.350052
#
# 0   tqwt_kurtosisValue_dec_31 tqwt_kurtosisValue_dec_32  \
# 502                  0.739879                  0.846829
# 427                  0.106639                   0.48521
# 597                  0.015421                   0.01233
# 14                   0.004443                  0.009377
# 590                  0.096505                   0.06483
#
# 0   tqwt_kurtosisValue_dec_33 tqwt_kurtosisValue_dec_34  \
# 502                  0.837002                  0.892476
# 427                  0.552852                  0.384805
# 597                  0.012027                  0.014759
# 14                   0.015227                  0.040713
# 590                  0.083298                  0.060621
#
# 0   tqwt_kurtosisValue_dec_35 tqwt_kurtosisValue_dec_36
# 502                   0.81123                  0.580653
# 427                  0.320759                  0.529293
# 597                  0.012902                   0.00449
# 14                   0.056058                  0.320158
# 590                  0.059502                  0.025206
#
# [5 rows x 753 columns]

# %%
y_train.head()
# Out:
# 9      1
# 432    1
# 428    1
# 511    1
# 131    1
# Name: class, dtype: object

# %%
y_test.head()
# Out:
# 502    1
# 427    1
# 597    0
# 14     1
# 590    0
# Name: class, dtype: object

# %% [markdown]
# **10 fold cross validation**

# %%
from sklearn.model_selection import ShuffleSplit, cross_val_score
cv = ShuffleSplit(n_splits = 10, random_state=0)

# %%
def k_fold_score(clf, cv) :
    score = cross_val_score(clf, X_train, y_train, cv=cv).mean()*100
    print('score using 10-fold cross validation:', score,'%')

# %% [markdown]
# **accuracy**

# %%
from sklearn.metrics import accuracy_score

def test_accuracy(decision) :
    decision.fit(X_train, y_train)
    predY = decision.predict(X_test)
    return accuracy_score(y_true=y_test, y_pred=predY)*100

def train_accuracy(decision) :
    decision.fit(X_train, y_train)
    predY = decision.predict(X_train)
    return accuracy_score(y_true=y_train, y_pred=predY)*100

# %% [markdown]
# **confusion matrix**

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def plot_confusion_matrix(decision) :
    decision.fit(X_train, y_train)
    predY = decision.predict(X_test)
    cf_matrix = confusion_matrix(y_test, predY)
    sns.heatmap(cf_matrix, annot=True)

# %% [markdown]
# ### decision tree:

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier() 
k_fold_score(clf, cv)

clf = tree.DecisionTreeClassifier(criterion = 'entropy')  #default: gini  
k_fold_score(clf, cv)

clf = tree.DecisionTreeClassifier(splitter= 'random')     #default: best  
k_fold_score(clf, cv)


clf = tree.DecisionTreeClassifier(max_features = 'log2')    # {“auto”, “sqrt”, “log2”}, default=None   
                                                            # max_features = auto ~ 2.4
                                                            # max_features = sqrt ~ 2.4
                                                            # max_features = log2 ~ 2.5
                                                            # max_features = None ~ 6
k_fold_score(clf, cv)



clf = tree.DecisionTreeClassifier(criterion = 'entropy', splitter= 'random')#
k_fold_score(clf, cv)

clf = tree.DecisionTreeClassifier(                       splitter= 'random' ,max_features = 'log2')
k_fold_score(clf, cv)

clf = tree.DecisionTreeClassifier(criterion = 'entropy'                    ,max_features = 'log2') 
k_fold_score(clf, cv)


clf = tree.DecisionTreeClassifier(criterion = 'entropy', splitter= 'random', max_features = 'log2')
k_fold_score(clf, cv)
# Out:
# score using 10-fold cross validation: 77.35849056603774 %
# score using 10-fold cross validation: 78.30188679245282 %
# score using 10-fold cross validation: 78.86792452830188 %
# score using 10-fold cross validation: 78.49056603773586 %
# score using 10-fold cross validation: 76.60377358490565 %
# score using 10-fold cross validation: 72.45283018867924 %
# score using 10-fold cross validation: 78.49056603773586 %
# score using 10-fold cross validation: 74.15094339622642 %

# %% [markdown]
# we don't focus on *max_depth* because time ist'n important
#
# it's clear that the best value for *min_samples_split* is 2. it can't be less than 2 and if it is greater than 2 it works faster but less score
#
# *min_samples_leaf*, *max_leaf_nodes*: it can decrease time and complexity and overfit. but we use k-fold cross value So we know it doesn't overfit
#
#
# there are not many differences between using auto, sqrt, and log2 for *max_features*. So I just compared *sqrt* and *default* value

# %% [markdown]
# now.. the best set of parameters is below:

# %%
clf = tree.DecisionTreeClassifier(criterion = 'entropy')
k_fold_score(clf, cv)

print("test accuracy-decision tree:" ,test_accuracy(clf))
print("train accuracy-decision tree:" ,train_accuracy(clf))
print()

plot_confusion_matrix(clf)
# Out:
# score using 10-fold cross validation: 78.30188679245283 %
# test accuracy-decision tree: 83.70044052863436
# train accuracy-decision tree: 100.0

# %%
clf = tree.DecisionTreeClassifier(criterion = 'entropy', splitter= 'random', max_features = 'log2')
k_fold_score(clf, cv)


print("test accuracy-decision tree:" ,test_accuracy(clf))
print("train accuracy-decision tree:" ,train_accuracy(clf))
print()

plot_confusion_matrix(clf)
# Out:
# score using 10-fold cross validation: 72.83018867924527 %
# test accuracy-decision tree: 77.09251101321586
# train accuracy-decision tree: 100.0

# %% [markdown]
# overfit!!!  DecisionTree does not work well

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier


neigh = KNeighborsClassifier()
k_fold_score(neigh, cv)

neigh = KNeighborsClassifier(weights='distance')          #default: uniform
k_fold_score(neigh, cv)

neigh = KNeighborsClassifier(algorithm = 'ball_tree')     #default:auto
k_fold_score(neigh, cv)
# Leaf size passed to BallTree or KDTree.


neigh = KNeighborsClassifier(algorithm= 'kd_tree')
k_fold_score(neigh, cv)


neigh = KNeighborsClassifier(algorithm='brute')
k_fold_score(neigh, cv)


neigh = KNeighborsClassifier(n_neighbors=1)
k_fold_score(neigh, cv)

neigh = KNeighborsClassifier(p=1,n_neighbors=1)           #default:2     
k_fold_score(neigh, cv)
# Out:
# score using 10-fold cross validation: 81.69811320754718 %
# score using 10-fold cross validation: 82.0754716981132 %
# score using 10-fold cross validation: 81.69811320754718 %
# score using 10-fold cross validation: 81.69811320754718 %
# score using 10-fold cross validation: 81.69811320754718 %
# score using 10-fold cross validation: 93.39622641509435 %
# score using 10-fold cross validation: 93.58490566037736 %

# %%
neigh = KNeighborsClassifier()
k_fold_score(neigh, cv)

print(test_accuracy(neigh))
print(train_accuracy(neigh))
print()

neigh = KNeighborsClassifier(p=1,n_neighbors=1)
k_fold_score(neigh, cv)
print(test_accuracy(neigh))
print(train_accuracy(neigh))
print()

neigh = KNeighborsClassifier(n_neighbors=1)
k_fold_score(neigh, cv)
print(test_accuracy(neigh))
print(train_accuracy(neigh))
print()
# Out:
# score using 10-fold cross validation: 81.69811320754718 %
# 88.98678414096916
# 92.62759924385632
#
# score using 10-fold cross validation: 93.58490566037736 %
# 94.7136563876652
# 100.0
#
# score using 10-fold cross validation: 93.39622641509435 %
# 93.83259911894272
# 100.0

# %%
neigh = KNeighborsClassifier()
k_fold_score(neigh, cv)

print(test_accuracy(neigh))
print(train_accuracy(neigh))
print()

plot_confusion_matrix(neigh)
# Out:
# score using 10-fold cross validation: 81.69811320754718 %
# 88.98678414096916
# 92.62759924385632

# %% [markdown]
# the first one does not overfit

# %% [markdown]
# ### random forest:

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()
k_fold_score(clf, cv)

clf = RandomForestClassifier(n_estimators=500)  #default : 100
k_fold_score(clf, cv)

clf = RandomForestClassifier(criterion='entropy') #default:”gini”
k_fold_score(clf, cv)

clf = RandomForestClassifier(max_features=None)  #max_features{“auto”, “sqrt”, “log2”} default=”auto”
k_fold_score(clf, cv)

clf = RandomForestClassifier(max_features= 'log2')
k_fold_score(clf, cv)

clf = RandomForestClassifier(bootstrap= False)
k_fold_score(clf, cv)


clf = RandomForestClassifier(oob_score= True)#Only available if bootstrap=True.
k_fold_score(clf, cv)


clf = RandomForestClassifier(warm_start=True)
k_fold_score(clf, cv)
 
clf = RandomForestClassifier(warm_start='balanced')#default=None
k_fold_score(clf, cv)

clf = RandomForestClassifier(ccp_alpha=0.01)    #default=0.0
k_fold_score(clf, cv)

clf = RandomForestClassifier(warm_start= 'balanced_subsample')
k_fold_score(clf, cv)
# Out:
# score using 10-fold cross validation: 83.77358490566039 %
# score using 10-fold cross validation: 83.39622641509435 %
# score using 10-fold cross validation: 82.83018867924528 %
# score using 10-fold cross validation: 83.58490566037737 %
# score using 10-fold cross validation: 81.13207547169813 %
# score using 10-fold cross validation: 85.84905660377359 %
# score using 10-fold cross validation: 84.33962264150944 %
# score using 10-fold cross validation: 84.33962264150944 %
# score using 10-fold cross validation: 83.20754716981133 %
# score using 10-fold cross validation: 81.50943396226415 %
# score using 10-fold cross validation: 83.2075471698113 %

# %% [markdown]
# RandomForest is really slow. and it's accuracy is't really better than other models

# %%
clf = RandomForestClassifier(bootstrap= False)
k_fold_score(clf, cv)
print(test_accuracy(clf))
print(train_accuracy(clf))
# Out:
# score using 10-fold cross validation: 85.47169811320755 %
# 92.07048458149781
# 100.0

# %% [markdown]
# It also overfit! So RandomForest is't a good model for this dataset

# %% [markdown]
# ### SVC

# %%
from sklearn.svm import SVC

clf = SVC()
k_fold_score(clf, cv)


clf = SVC(C=10)    #default=1
k_fold_score(clf, cv)

clf = SVC(C=13)
k_fold_score(clf, cv)

clf = SVC(C=15)
k_fold_score(clf, cv)

clf = SVC(gamma=1)
k_fold_score(clf, cv)

clf = SVC(C=13, gamma=1)
k_fold_score(clf, cv)

clf = SVC(coef0=-0.2)    #default=0
k_fold_score(clf, cv)

clf = SVC(coef0=0.2)
k_fold_score(clf, cv)

clf = SVC(coef0=1)
k_fold_score(clf, cv)

clf = SVC(kernel="linear")
k_fold_score(clf, cv)


clf = SVC(kernel="sigmoid")
k_fold_score(clf, cv)


clf = SVC(kernel="linear",C=13)
k_fold_score(clf, cv)


clf = SVC(kernel="sigmoid",C=13, coef0=0.20)
k_fold_score(clf, cv)
# Out:
# score using 10-fold cross validation: 80.37735849056604 %
# score using 10-fold cross validation: 83.96226415094341 %
# score using 10-fold cross validation: 84.33962264150944 %
# score using 10-fold cross validation: 84.52830188679246 %
# score using 10-fold cross validation: 74.52830188679246 %
# score using 10-fold cross validation: 74.52830188679246 %
# score using 10-fold cross validation: 80.37735849056604 %
# score using 10-fold cross validation: 80.37735849056604 %
# score using 10-fold cross validation: 80.37735849056604 %
# score using 10-fold cross validation: 84.90566037735849 %
# score using 10-fold cross validation: 74.52830188679246 %
# score using 10-fold cross validation: 83.58490566037734 %
# score using 10-fold cross validation: 75.84905660377358 %

# %%
clf = SVC(C=13)
k_fold_score(clf, cv)

print(test_accuracy(neigh))
print(train_accuracy(neigh))
print()

# plot_confusion_matrix(neigh)
clf = SVC(C=15)
k_fold_score(clf, cv)

print(test_accuracy(neigh))
print(train_accuracy(neigh))
print()

plot_confusion_matrix(neigh)
# Out:
# score using 10-fold cross validation: 84.33962264150944 %
# 88.98678414096916
# 92.62759924385632
#
# score using 10-fold cross validation: 84.52830188679246 %
# 88.98678414096916
# 92.62759924385632

# %% [markdown]
# ### PCA:

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=600)
X = pd.DataFrame(pca.fit_transform(X))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
clf = SVC(C=15)
k_fold_score(clf, cv)
print(test_accuracy(clf))
print(train_accuracy(clf))
print()

neigh = KNeighborsClassifier()
k_fold_score(neigh, cv)
print(test_accuracy(neigh))
print(train_accuracy(neigh))
print()


clf = RandomForestClassifier(bootstrap= False)
k_fold_score(clf, cv)
print(test_accuracy(clf))
print(train_accuracy(clf))
print()


clf = tree.DecisionTreeClassifier(criterion = 'entropy', splitter= 'random', max_features = 'log2')
k_fold_score(clf, cv)
print("test accuracy-decision tree:" ,test_accuracy(clf))
print("train accuracy-decision tree:" ,train_accuracy(clf))
print()
# Out:
# score using 10-fold cross validation: 89.43396226415096 %
# 94.7136563876652
# 100.0
#
# score using 10-fold cross validation: 81.69811320754718 %
# 88.98678414096916
# 92.62759924385632
#
# score using 10-fold cross validation: 75.28301886792454 %
# 76.65198237885463
# 100.0
#
# score using 10-fold cross validation: 61.13207547169811 %
# test accuracy-decision tree: 56.38766519823789
# train accuracy-decision tree: 100.0

# %%
pca = PCA(n_components=100)
X = pd.DataFrame(pca.fit_transform(X))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
clf = SVC(C=15)
k_fold_score(clf, cv)
print(test_accuracy(clf))
print(train_accuracy(clf))
print()

neigh = KNeighborsClassifier()
k_fold_score(neigh, cv)
print(test_accuracy(neigh))
print(train_accuracy(neigh))
print()


clf = RandomForestClassifier(bootstrap= False)
k_fold_score(clf, cv)
print(test_accuracy(clf))
print(train_accuracy(clf))
print()


clf = tree.DecisionTreeClassifier(criterion = 'entropy', splitter= 'random', max_features = 'log2')
k_fold_score(clf, cv)
print("test accuracy-decision tree:" ,test_accuracy(clf))
print("train accuracy-decision tree:" ,train_accuracy(clf))
print()
# Out:
# score using 10-fold cross validation: 89.62264150943395 %
# 95.59471365638767
# 100.0
#
# score using 10-fold cross validation: 82.64150943396226 %
# 89.86784140969164
# 92.24952741020795
#
# score using 10-fold cross validation: 81.1320754716981 %
# 86.78414096916299
# 100.0
#
# score using 10-fold cross validation: 69.24528301886792 %
# test accuracy-decision tree: 66.07929515418502
# train accuracy-decision tree: 100.0

# %%
pca = PCA(n_components=50)
X = pd.DataFrame(pca.fit_transform(X))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
clf = SVC(C=15)
k_fold_score(clf, cv)
print(test_accuracy(clf))
print(train_accuracy(clf))
print()

neigh = KNeighborsClassifier()
k_fold_score(neigh, cv)
print(test_accuracy(neigh))
print(train_accuracy(neigh))
print()


clf = RandomForestClassifier(bootstrap= False)
k_fold_score(clf, cv)
print(test_accuracy(clf))
print(train_accuracy(clf))
print()


clf = tree.DecisionTreeClassifier(criterion = 'entropy', splitter= 'random', max_features = 'log2')
k_fold_score(clf, cv)
print("test accuracy-decision tree:" ,test_accuracy(clf))
print("train accuracy-decision tree:" ,train_accuracy(clf))
print()
# Out:
# score using 10-fold cross validation: 90.75471698113209 %
# 95.15418502202643
# 100.0
#
# score using 10-fold cross validation: 83.2075471698113 %
# 87.22466960352423
# 90.92627599243856
#
# score using 10-fold cross validation: 83.39622641509435 %
# 90.30837004405286
# 100.0
#
# score using 10-fold cross validation: 69.43396226415094 %
# test accuracy-decision tree: 71.80616740088107
# train accuracy-decision tree: 100.0
